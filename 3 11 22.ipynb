# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data (1).csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string())    # to print the entire data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.shape
# Out:
# (169, 4)

# %%
#finding the null value
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
#cleaning the null values
df1=df.dropna(inplace=True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
#filling na values
df.fillna(130,inplace=True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df=pd.read_csv("data (1).csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x=df["Calories"].mean()

# %%
x
# Out:
# 375.79024390243916

# %%
df["Calories"].fillna(x,inplace=True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 0          60    110       130   409.100000
# 1          60    117       145   479.000000
# 2          60    103       135   340.000000
# 3          45    109       175   282.400000
# 4          45    117       148   406.000000
# 5          60    102       127   300.000000
# 6          60    110       136   374.000000
# 7          45    104       134   253.300000
# 8          30    109       133   195.100000
# 9          60     98       124   269.000000
# 10         60    103       147   329.300000
# 11         60    100       120   250.700000
# 12         60    106       128   345.300000
# 13         60    104       132   379.300000
# 14         60     98       123   275.000000
# 15         60     98       120   215.200000
# 16         60    100       120   300.000000
# 17         45     90       112   375.790244
# 18         60    103       123   323.000000
# 19         45     97       125   243.000000
# ...

# %%
x=df.duplicated()
print(df.duplicated())


#duplication
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
print(x.to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36      True
# 37      True
# 38      True
# 39     False
# 40      True
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]

# %%
y=df.duplicated().sum()

# %%
y
# Out:
# 0

# %%
#data correlation(how each values are related)
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.162098  0.003578  0.921907
# Pulse    -0.162098  1.000000  0.787035  0.015408
# Maxpulse  0.003578  0.787035  1.000000  0.194031
# Calories  0.921907  0.015408  0.194031  1.000000

# %%
dp=sb.heatmap(df.corr(),cmap="Accent",annot=True)

# %%
df.plot()
plt.show()

# %%
#scaterplot
df.plot(kind='scatter', x='Duration',y='Calories')
plt.show()

# %%
df.plot(kind='scatter', x='Duration',y='Maxpulse')
plt.show()

# %%
#Draw 2 plot

import matplotlib.pyplot as plt
import numpy as np


#pltot1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)




#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#pltot1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,1)
plt.plot(x,y)




#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,2)
plt.plot(x,y)

#pltot3

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,3)
plt.plot(x,y)




#plot4
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,4)
plt.plot(x,y)

#pltot5

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,5)
plt.plot(x,y)




#plot6
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()

# %%
#super title
import matplotlib.pyplot as plt
import numpy as np


#pltot1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")




#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOPE")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y,color="red")
plt.title("first")
plt.show()

# %%
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.bar(x,y,color="blue")
plt.title("first")
plt.show()

# %%
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.barh(x,y,color="black")
plt.title("first")
plt.show()

# %%
x=np.random.normal(170,10,250)
print(x)
# Out:
# [158.57322934 185.03268851 174.08518058 168.11278713 170.82145511
#  184.35288481 169.79763254 175.4610211  182.73922104 169.62294436
#  169.18175428 174.90619331 146.80927164 182.97964339 174.48815462
#  169.21052754 156.3754657  169.45487799 158.23019491 182.05748263
#  191.42981491 183.52803367 165.75497226 181.01440407 174.84094549
#  159.69086373 170.33006695 162.32406304 182.36039478 186.60412504
#  170.89187948 172.42571687 162.63030248 170.45286851 174.68239175
#  155.73060397 158.25456803 180.20169843 161.56658976 163.59084084
#  171.82677789 166.17569173 167.61328627 160.82000754 166.62736967
#  175.375827   165.23956225 155.14040837 158.61504772 154.54817848
#  178.21342565 166.232414   160.6812046  179.02802142 185.49658672
#  169.91671135 173.27014537 178.49137042 162.64445256 180.32742569
#  167.66317197 173.77198382 169.0090528  166.56903036 162.64285175
#  155.81527256 164.79661708 185.46919609 185.83491924 186.22031111
# ...

# %%
plt.hist(x,color="black")
plt.show()

# %%
y=np.array([30,40,50,60])
name=['ram','ros','som','riya']
color=["blue","red","green","yellow"]


plt.pie(y,labels=name,startangle=40,explode=[0.1,0.1,0.1,0.1,],shadow=True,colors=color)
plt.legend(title = "four name:")
plt.show()

# %%
x=np.array([5,7,8,7,2])
y1=[5,7,8,7,2]
y2=[4,11,12,9,6]
y3=[88,10,2,10,87]
plt.bar(x-.2,y1,width=0.4)
plt.bar(x+.2,y2,width=0.4)

plt.show()

# %%
#Group chart
x=np.array([5,7,8,7,2])
y1=[5,7,8,7,2]
y2=[4,11,12,9,6]
y3=[88,10,2,10,87]
plt.bar(x-.2,y1,width=0.4,color="violet")
plt.bar(x+.2,y2,width=0.4,color="blue")

plt.title("first")
plt.xticks(x,[2,4,6,8,10])
plt.legend(["a","b","c"])
plt.xlabel("x axis")
plt.ylabel("y axis")





plt.show()

# %%
#stack chart
x=["a","b","c","d"]
y1=np.array([5,7,8,7])
y2=np.array([4,11,12,9])
y3=np.array([4,9,10,56])
y4=np.array([12,4,6,10])
plt.bar(x,y1,width=0.4,color="violet")
plt.bar(x,y2,width=0.4,color="yellow",bottom=y1)
plt.bar(x,y3,width=0.4,color="black",bottom=y1+y2)
plt.bar(x,y4,width=0.4,color="blue",bottom=y1+y2+y3)
plt.show()

# %%
#create a data frame
import pandas as pd
df=pd.DataFrame({'round':["round1","round2","round3","round4","round5"],"score1":[30,40,50,60,70],"score2":[10,20,30,60,70],"score3":[70,40,50,60,70],"score4":[30,40,20,60,70],"score5":[30,40,90,60,70]})

# %%
df
# Out:
#     round  score1  score2  score3  score4  score5
# 0  round1      30      10      70      30      30
# 1  round2      40      20      40      40      40
# 2  round3      50      30      50      20      90
# 3  round4      60      60      60      60      60
# 4  round5      70      70      70      70      70

# %%
df.plot(kind='bar',x='round',stacked=True,color=["black","yellow","red","silver","violet"])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("student progress")

plt.show()
