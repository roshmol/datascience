# %%
import numpy as np

from scipy import stats

# %%
a=[81,82,83,84,85,85,87]
np.std(a)
import numpy as np
a=[105,282,383,484,285,585,687]
np.std(a)
# Out:
# 184.42796281851557

# %%
age=[10,34,2,5,7,9,16,34,67,34,68,56,89,90,23,24,26,36,39,57,48,29,34,56,78,98]
x=np.percentile(age,75)

# %%
x
# Out:
# 56.75

# %%
#what is the age 90% people younger
age=[10,34,2,5,7,9,16,34,67,34,68,56,89,90,23,24,26,36,39,57,48,29,34,56,78,98]
x=np.percentile(age,90)

# %%
x
# Out:
# 83.5

# %%
import matplotlib.pyplot as plt
y=np.random.uniform(0.0,5.0,100000)

# %%
y
# Out:
# array([1.26831416, 0.55539278, 1.78882535, ..., 4.85529768, 3.7833294 ,
#        1.29964039])

# %%
plt.hist(y,bins=100)#histogram
# Out:
# (array([1027., 1009., 1002., 1005., 1044.,  950., 1020., 1010.,  998.,
#          953.,  955., 1035., 1020.,  977.,  992., 1023.,  988.,  940.,
#          997.,  984.,  994.,  987., 1037.,  933.,  987., 1076.,  998.,
#          984., 1002., 1024.,  978.,  984., 1008., 1039.,  958., 1032.,
#         1040., 1012.,  977.,  953., 1030., 1004., 1001., 1011.,  902.,
#          986., 1034.,  989., 1022.,  998., 1063.,  982., 1014.,  971.,
#          981., 1003.,  929., 1025., 1020.,  935., 1009.,  990.,  986.,
#          970.,  993., 1045., 1025., 1021., 1041., 1069.,  968.,  980.,
#          925., 1037.,  990., 1001., 1049.,  981., 1009., 1032., 1024.,
#         1050.,  988.,  999., 1012.,  988.,  972., 1000., 1020.,  968.,
#         1000.,  990., 1032., 1003.,  976.,  967.,  988.,  995.,  972.,
#         1103.]),
#  array([1.83532409e-05, 5.00181416e-02, 1.00017930e-01, 1.50017718e-01,
#         2.00017507e-01, 2.50017295e-01, 3.00017083e-01, 3.50016872e-01,
#         4.00016660e-01, 4.50016448e-01, 5.00016237e-01, 5.50016025e-01,
#         6.00015813e-01, 6.50015602e-01, 7.00015390e-01, 7.50015178e-01,
#         8.00014967e-01, 8.50014755e-01, 9.00014543e-01, 9.50014332e-01,
#         1.00001412e+00, 1.05001391e+00, 1.10001370e+00, 1.15001349e+00,
#         1.20001327e+00, 1.25001306e+00, 1.30001285e+00, 1.35001264e+00,
#         1.40001243e+00, 1.45001222e+00, 1.50001200e+00, 1.55001179e+00,
#         1.60001158e+00, 1.65001137e+00, 1.70001116e+00, 1.75001095e+00,
#         1.80001073e+00, 1.85001052e+00, 1.90001031e+00, 1.95001010e+00,
#         2.00000989e+00, 2.05000968e+00, 2.10000946e+00, 2.15000925e+00,
#         2.20000904e+00, 2.25000883e+00, 2.30000862e+00, 2.35000841e+00,
#         2.40000819e+00, 2.45000798e+00, 2.50000777e+00, 2.55000756e+00,
#         2.60000735e+00, 2.65000714e+00, 2.70000692e+00, 2.75000671e+00,
#         2.80000650e+00, 2.85000629e+00, 2.90000608e+00, 2.95000587e+00,
#         3.00000565e+00, 3.05000544e+00, 3.10000523e+00, 3.15000502e+00,
#         3.20000481e+00, 3.25000460e+00, 3.30000438e+00, 3.35000417e+00,
#         3.40000396e+00, 3.45000375e+00, 3.50000354e+00, 3.55000333e+00,
#         3.60000311e+00, 3.65000290e+00, 3.70000269e+00, 3.75000248e+00,
#         3.80000227e+00, 3.85000206e+00, 3.90000184e+00, 3.95000163e+00,
#         4.00000142e+00, 4.05000121e+00, 4.10000100e+00, 4.15000079e+00,
#         4.20000057e+00, 4.25000036e+00, 4.30000015e+00, 4.34999994e+00,
#         4.39999973e+00, 4.44999952e+00, 4.49999930e+00, 4.54999909e+00,
#         4.59999888e+00, 4.64999867e+00, 4.69999846e+00, 4.74999825e+00,
#         4.79999803e+00, 4.84999782e+00, 4.89999761e+00, 4.94999740e+00,
#         4.99999719e+00]),
#  <BarContainer object of 100 artists>)

# %%
b=np.random.normal(5.0,1.0,100000)
b
# Out:
# array([4.67046152, 4.14303625, 6.46129051, ..., 5.49690384, 4.99830589,
#        4.92143392])

# %%
plt.hist(b,color='pink',bins=100)
plt.show()

# %%
x=[1,2,9,4,5,6,7]
y=[100,80,1,4,60,30,20]
plt.scatter(x,y)
plt.show()

# %%
x=np.random.normal(5.0,1.0,1000)
y=np.random.normal(10.0,2.0,1000)
plt.scatter(x,y)
plt.show()

# %%
x=[1,2,9,4,5,6,7]
y=[100,80,1,4,60,30,20]
m,c,r,p,std_err=stats.linregress(x,y)
def fun(x):
    return(m*x)+c

plt.scatter(x,y)
p=list(map(fun,x))
plt.scatter(x,y)
plt.plot(x,p)
plt.show()

# %%
age=np.array(40,50,68,78,34,23,13)
glucose=np.array(82,70,58,60,23,40)
